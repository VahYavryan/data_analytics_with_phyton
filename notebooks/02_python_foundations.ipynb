# %% [markdown]
# ## Data Types

# %% [markdown]
# ### Integers

# %%
v = 21
v
# Out:
# 21

# %%
a = '22'
a == v
# Out:
# False

# %%
v = a

# %%
type(a)
# Out:
# str

# %% [markdown]
# ### Float

# %%
x = 6
x = 5.5
x
# Out:
# 5.5

# %%
type(x)
# Out:
# float

# %%
a = 6
b = 3
c = 2.5
a + b + c
# Out:
# 11.5

# %%
d = a + b + c

# %%
float(int(d))
# Out:
# 11.0

# %%
type(d)
# Out:
# float

# %%
a = 7
b = 3

# %%
div1=a/b
div2=a//b

# %%
print(f"simple division:{div1}")
print(f"integer division:{div2}")
# Out:
# simple division:2.3333333333333335
# integer division:2

# %% [markdown]
# ### String

# %%
first_name = "Vahe"
last_name = "Yavryan"

# %%
type(last_name)
# Out:
# str

# %%
a = '22'

# %%
a + '5'
# Out:
# '225'

# %%
full_name = first_name + ' ' + last_name
full_name
# Out:
# 'Vahe Yavryan'

# %%
N = 4
power = 3
for i in range(N):
    print(f'{i} power of {power} {i**power}')
# Out:
# 0 power of 3 0
# 1 power of 3 1
# 2 power of 3 8
# 3 power of 3 27

# %% [markdown]
# ### Boolean Values

# %%
is_active1 = True
is_active2 = False

# %%
type(is_active1)
# Out:
# bool

# %%
x = 42
x> 40
# Out:
# True

# %%
x = 42

# %%
x == 42
x<=42
# Out:
# True

# %%
x = '42'

# %%
x
# Out:
# '42'

# %%
x = 42
y = 32
z = x + y

type(x + y)
# Out:
# int

# %%
type(z)
# Out:
# int

# %%
var_name = 'value'
